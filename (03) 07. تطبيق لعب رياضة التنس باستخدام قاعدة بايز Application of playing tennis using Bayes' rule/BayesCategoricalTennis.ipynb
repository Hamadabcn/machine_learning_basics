# %%
import pandas as pd

from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('play_tennis_train.csv')

le_outlook = LabelEncoder()
le_outlook.fit(df['outlook'])

le_temp = LabelEncoder()
le_temp.fit(df['temp'])

le_humidity = LabelEncoder()
le_humidity.fit(df['humidity'])

le_wind = LabelEncoder()
le_wind.fit(df['wind'])

le_play = LabelEncoder()
le_play.fit(df['play'])

df['outlook_num'] = le_outlook.transform(df['outlook'])
df['temp_num'] = le_temp.transform(df['temp'])
df['humidity_num'] = le_humidity.transform(df['humidity'])
df['wind_num'] = le_wind.transform(df['wind'])
df['play_num'] = le_play.transform(df['play'])

df
# Out:
#     day   outlook  temp humidity    wind play  outlook_num  temp_num  \
# 0    D1     Sunny   Hot     High    Weak   No            2         1
# 1    D2     Sunny   Hot     High  Strong   No            2         1
# 2    D3  Overcast   Hot     High    Weak  Yes            0         1
# 3    D4      Rain  Mild     High    Weak  Yes            1         2
# 4    D5      Rain  Cool   Normal    Weak  Yes            1         0
# 5    D6      Rain  Cool   Normal  Strong   No            1         0
# 6    D7  Overcast  Cool   Normal  Strong  Yes            0         0
# 7    D8     Sunny  Mild     High    Weak   No            2         2
# 8    D9     Sunny  Cool   Normal    Weak  Yes            2         0
# 9   D10      Rain  Mild   Normal    Weak  Yes            1         2
# 10  D11     Sunny  Mild   Normal  Strong  Yes            2         2
# 11  D12  Overcast  Mild     High  Strong  Yes            0         2
# 12  D13  Overcast   Hot   Normal    Weak  Yes            0         1
# ...

# %%
from sklearn.naive_bayes import CategoricalNB # categorical naive bayes

x = df[['outlook_num', 'temp_num', 'humidity_num', 'wind_num']]
y = df['play_num']

model = CategoricalNB(alpha=0)

model.fit(x, y)
# Out:
# C:\Users\mohbc\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:624: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# C:\Users\mohbc\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:633: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# CategoricalNB(alpha=0)

# %%
newDay = ['Sunny', 'Cool', 'High', 'Strong']

outlook_num = le_outlook.transform([newDay[0]])[0]
temp_num = le_temp.transform([newDay[1]])[0]
humidity_num = le_humidity.transform([newDay[2]])[0]
wind_num = le_wind.transform([newDay[3]])[0]

new_Day_num = [[outlook_num, temp_num, humidity_num, wind_num]]
print(new_Day_num)

new_Day_num_df = pd.DataFrame(new_Day_num, columns=['outlook_num', 'temp_num', 'humidity_num', 'wind_num'])

predclass_num = model.predict(new_Day_num_df)
print(predclass_num)

predclass = le_play.inverse_transform(predclass_num)
print(predclass)
# Out:
# [[2, 0, 0, 0]]
# [0]
# ['No']

# %%
prob = model.predict_proba(new_Day_num_df)
print(prob)
# Out:
# [[0.79541735 0.20458265]]

# %%
y_pred = model.predict(x)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('\nAccuracy:{:.2f}\n'.format(100 * accuracy_score(y, y_pred)))
print('\nPrecision:{:.2f}\n'.format(100 * precision_score(y, y_pred)))
print('\nRecall:{:.2f}\n'.format(100 * recall_score(y, y_pred)))
print('\nF1:{:.2f}\n'.format(100 * f1_score(y, y_pred)))
# Out:
# Accuracy:92.86
#
#
# Precision:90.00
#
#
# Recall:100.00
#
#
# F1:94.74
